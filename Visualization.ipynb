# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
attendance = pd.read_csv('../project-II/attendance.csv')
attendance
# Out:
#                          Team    Position  Average  Capacity  \
# 0                  Olympiacos  Final Four    10454     11847
# 1                   Barcelona  Final Four     6357      7585
# 2                 Real Madrid  Final Four     8141     13109
# 3                   AS Monaco  Final Four     4392      5000
# 4   Maccabi Playtika Tel Aviv     Playoff    10338     10383
# 5        Partizan Mozzart Bet     Playoff    17938     19394
# 6                    Žalgiris     Playoff    14836     15415
# 7             Fenerbahçe Beko     Playoff    10476     13059
# 8              Cazoo Baskonia         Out     8919     15504
# 9                Anadolu Efes         Out    13099     16000
# 10   EA7 Emporio Armani Milan         Out     9443     12700
# 11            Valencia Basket         Out     6059      8500
# 12   Virtus Segafredo Bologna         Out     6136      9980
# 13              Bayern Munich         Out     5951      6500
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt



sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

colores = ['red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey']
plot = sns.barplot(x='Team', y='Percentage of attendance', data = attendance, palette= colores)


plt.xlabel('Teams')
plt.ylabel('% of attendance')
plt.title('% of attendance per team')
plt.xticks(rotation=45, fontsize = 8)

plt.show()

# %%
star_players_teams = pd.read_csv('star_count.csv')
star_players_teams
# Out:
#                          Team  Players Count    Position
# 0                   AS Monaco              3  Final Four
# 1   Maccabi Playtika Tel Aviv              2     Playoff
# 2                Anadolu Efes              2         Out
# 3               Panathinaikos              2         Out
# 4        Partizan Mozzart Bet              2     Playoff
# 5             Fenerbahçe Beko              2     Playoff
# 6              Cazoo Baskonia              2         Out
# 7   Crvena zvezda Meridianbet              2         Out
# 8                  Olympiacos              1  Final Four
# 9                    Žalgiris              1     Playoff
# 10                  Barcelona              1  Final Four
# 11   EA7 Emporio Armani Milan              1         Out
# 12                Real Madrid              1  Final Four
# 13                 LDLC ASVEL              1         Out
# 14            Valencia Basket              1         Out

# %%
import seaborn as sns
import matplotlib.pyplot as plt



sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

colores = ['red', 'blue', 'grey', 'grey', 'blue', 'blue', 'grey', 'grey', 'red', 'blue', 'red', 'grey', 'red', 'grey', 'grey']
plot = sns.barplot(x='Team', y='Players Count', data = star_players_teams, palette= colores)


plt.xlabel('Teams')
plt.ylabel('Players Count')
plt.title('Star Players per Team')
plt.xticks(rotation=45, fontsize = 8)

plt.show()
